# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from environment import Environment

# %%
X = np.linspace(-3,3,30)
y = np.sin(X)

# %%
env = Environment(X = np.array([1]),y = np.array(np.sin([1])), func = np.sin, model = 'NN',model_param = {'nb_nodes':40,'nb_layers':4})
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 40]              80
#                ELU-2                   [-1, 40]               0
#             Linear-3                   [-1, 40]           1,640
#                ELU-4                   [-1, 40]               0
#             Linear-5                   [-1, 40]           1,640
#                ELU-6                   [-1, 40]               0
#             Linear-7                    [-1, 1]              41
# ================================================================
# Total params: 3,401
# Trainable params: 3,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# <model.NN.NN_model object at 0x1050b9df0>

# %%
env.toy_Plot(X)

# %%
for i in 
env.Step([0])
# Out:
# (array([-0.35890803,  0.29183352,  0.40060499, ..., -0.15428923,
#         -0.0482153 ,  0.11703131]),
#  -0.011105755344033241,
#  False,
#  True)

# %%
env.Reset()
# Out:
# array([-0.35881925,  0.29376176,  0.39678273, ..., -0.1544463 ,
#        -0.04266608,  0.11885454])
