# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from environment import Environment

# %%
X = np.linspace(-3,3,30)
y = np.sin(X)

# %%
env = Environment(X = np.array([1]),y = np.array(np.sin([1])), func = np.sin, model = 'NN',model_param = {'nb_nodes':40,'nb_layers':4})
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                   [-1, 40]              80
#                ELU-2                   [-1, 40]               0
#             Linear-3                   [-1, 40]           1,640
#                ELU-4                   [-1, 40]               0
#             Linear-5                   [-1, 40]           1,640
#                ELU-6                   [-1, 40]               0
#             Linear-7                    [-1, 1]              41
# ...
# Total params: 3,401
# Trainable params: 3,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------
# ...

# %%
env.toy_Plot(X)

# %%
for i in np.linspace(-3,3,30):
    env.Step([i])

# %%
env.toy_Plot(X)

# %%
env.Reset()
# Out:
# array([-0.66603386,  0.818241  , -0.39112121, ...,  0.06827839,
#         0.09048533,  0.10524305])

# %%
env.toy_Plot(X)
